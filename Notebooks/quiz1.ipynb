# %%
import numpy as np 
import pandas as pd 

df = pd.read_csv('./datasets/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
len(df[df["Embarked"] == "C"])/len(df)
# Out:
# 0.18855218855218855

# %%
embarked_c = df[df["Embarked"] == "C"]
embarked_c
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# 31            32         1       1
# 34            35         0       1
# 36            37         1       3
# 39            40         1       3
# 42            43         0       3
# 43            44         1       2
# 48            49         0       3
# 52            53         1       1
# 54            55         0       1
# 57            58         0       3
# 60            61         0       3
# 64            65         0       1
# 65            66         1       3
# 73            74         0       3
# 96            97         0       1
# 97            98         1       1
# 111          112         0       3
# 114          115         0       3
# 118          119         0       1
# 122          123         0       2
# ...

# %%
len(embarked_c[embarked_c["Sex"] == "female"])/len(df[df["Sex"] == "female"])
# Out:
# 0.23248407643312102

# %%
len(df[df["Embarked"] == "C" && df["Sex"] == "female"])
# Out:
#   File "<ipython-input-11-691fb4c72e71>", line 1
#     len(df[df["Embarked"] == "C" && df["Sex"] == "female"])
#                                   ^
# SyntaxError: invalid syntax

# %%
df_male = df[df["Sex"] == "male"]

# %%
df_sur = (df_male[df_male["Survived"] == 1]["Age"]).dropna()
df_sur = (df_male[df_male["Survived"] == 1]["Age"]).dropna().values

# %%
import numpy as np

data = np.array([1, 3, 5, 2, 3, 7, 8, 4, 10, 0, 6, 7, 3, 0, 3, 0, 5, 7, 10, 1, 4, 9, 3])

#  Complete this function by having the function return the average value of our dataset.
def mean_compute(dataset):
    sum = 0
    for num in dataset:
        sum += num
    return sum/len(dataset)

def compute_mean(dataset):
    """ Main function that calculates the average value across our data. """
    
    return sum(dataset)/len(dataset)

compute_mean(data)
mean_compute(data)
# Out:
# 4.391304347826087

# %%
compute_mean(df_sur)
# Out:
# 27.276021505376345

# %%
df[(df['Survived'] ==1) & (df['Sex'] == 'male')]['Age'].dropna().agg(compute_mean)
# Out:
# 27.276021505376345

# %%
# TODO: Complete this function by having the function return the exact true median value of our dataset.
# HINT: Consider using DataFrame slicing to help with identifying the correct median value(s).
def compute_median(dataset):
    """ Main function that determines the median value across our data. """
    count = len(dataset)
    sort = sorted(dataset)
    
    if count < 1:
        # TODO: Complete this if-statement
        return None
    if count % 2 == 1:
        # Complete this if-statement
        
        middle_index = (count - 1) // 2
        median = sort[middle_index]
        return median
    else:
        middle_index = (count - 1) // 2
        median = sort[middle_index]
compute_median(data)
# Out:
# 4

# %%
ls_fare = df["Fare"].dropna().values
np.percentile(ls_fare, 75)
# Out:
# 31.0

# %%
df_fare = df[df["Fare"].dropna() <= 31]

# %%
len(df_fare)/len(df)
# Out:
# 0.7508417508417509
